# %% [markdown]
# # Unity Banana Environment Results

# %%
import os
import sys

print("Adding project home to path")
nb_dir = os.path.split(os.getcwd())[0]
PROJECT_PATH = os.path.split(nb_dir)[0]

if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)

# %%
# %load_ext autoreload
# %autoreload 2

from Agents.Base_Agent import Base_Agent
from Environments.Unity_Environments.Unity_Banana_Environment import Unity_Banana_Environment
from Agents.DQN_Agents.DQN_Agent import DQN_Agent
from Agents.DQN_Agents.DQN_Agent_With_Fixed_Q_Targets import DQN_Agent_With_Fixed_Q_Targets
from Agents.DQN_Agents.DDQN_Agent import DDQN_Agent
from Utilities import print_two_lines, save_score_results, visualise_results_by_agent
import numpy as np
import torch

ENVIRONMENT = None
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SEED = 100
ROLLING_SCORE_LENGTH = 100
AVERAGE_SCORE_REQUIRED = 13
EPISODES_TO_RUN = 1000
FILE_TO_SAVE_DATA_RESULTS = "Episode_results_by_agent.npy"
UNITY_FILE_NAME = "/data/Banana_Linux_NoVis/Banana.x86_64"

if ENVIRONMENT is None:
    ENVIRONMENT = Unity_Banana_Environment(UNITY_FILE_NAME)

hyperparameters = {
    "learning_rate": 5e-4,
    "batch_size": 64,
    "buffer_size": int(1e5),
    "fc_units": [30, 30],
    "epsilon": 0.05,
    "gamma":  0.99,
    "tau": 1e-3,
    "update_every_n_steps": 1,
    "alpha": 0.5,
    "incremental_priority": 1e-5
}

results = {}

# DDQN_Agent_With_Fixed_Q_Targets_And_Prioritised_Experience_Replay

agent_number = 1

agents = [DQN_Agent, DQN_Agent_With_Fixed_Q_Targets, DDQN_Agent]                                        

for agent_class in agents: 
                                        
    agent_name = agent_class.__name__
    print("\033[1m" + "{}: {}".format(agent_number, agent_name) + "\033[0m")
    
    agent = agent_class(ENVIRONMENT, SEED, hyperparameters, 
                        ROLLING_SCORE_LENGTH, AVERAGE_SCORE_REQUIRED, agent_name)
    game_scores, rolling_scores = agent.run_game_n_times(num_episodes_to_run=EPISODES_TO_RUN)    
    results[agent_name] = [game_scores, rolling_scores]
    agent_number += 1
    print_two_lines()
    
    
save_score_results(FILE_TO_SAVE_DATA_RESULTS, results)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# 1: DQN_Agent
# DQN_Agent achieved required score at episode 521
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#
# 2: DQN_Agent_With_Fixed_Q_Targets
# DQN_Agent_With_Fixed_Q_Targets achieved required score at episode 349
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#
# 3: DDQN_Agent
# DDQN_Agent achieved required score at episode 289
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------

# %%
visualise_results_by_agent(agents, results, AVERAGE_SCORE_REQUIRED)
